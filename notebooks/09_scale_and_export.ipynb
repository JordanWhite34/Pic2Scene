# %% [markdown]
# # 09 Scale and Export
#
# **Purpose:** Set real-world scale and export the final mesh as STL.

# %% [markdown]
#     ## Inputs
#     - Final mesh
# - Known scale reference or desired target dimensions
#
#     ## Outputs
#     - Scaled mesh
# - Final STL export

# %% [markdown]
#     ## What needs to be done
#     - [ ] Decide how scale will be recovered
# - [ ] Apply uniform scaling to the mesh
# - [ ] Check final dimensions
# - [ ] Export STL
# - [ ] Optionally export OBJ / PLY for comparison
# - [ ] Document final settings used

# %% [markdown]
# ## Notes
# - Keep code in this notebook focused on experimentation and visualization.
# - As soon as a block becomes reusable, move it into `src/`.
# - Save intermediate artifacts so later notebooks do not need to recompute everything.

# %% [markdown]
# ## Imports and Paths

# %% [markdown]
# ## Load Final Mesh

# %% [markdown]
# ## Compute / Apply Scale

# %% [markdown]
# ## Validate Dimensions

# %% [markdown]
# ## Export STL and Other Formats
