# %% [markdown]
# # 04 Initial Triangulation
#
# **Purpose:** Build the first sparse 3D point cloud from two views.

# %% [markdown]
#     ## Inputs
#     - Relative camera pose
# - Inlier correspondences from two views
#
#     ## Outputs
#     - Initial sparse point cloud
# - PLY or NPZ export of 3D points

# %% [markdown]
#     ## What needs to be done
#     - [ ] Construct projection matrices for the first two cameras
# - [ ] Triangulate matched points
# - [ ] Convert homogeneous coordinates to 3D
# - [ ] Filter invalid or far-out points
# - [ ] Visualize the sparse cloud
# - [ ] Save sparse cloud to disk

# %% [markdown]
# ## Notes
# - Keep code in this notebook focused on experimentation and visualization.
# - As soon as a block becomes reusable, move it into `src/`.
# - Save intermediate artifacts so later notebooks do not need to recompute everything.

# %% [markdown]
# ## Imports and Paths

# %% [markdown]
# ## Load Poses and Inliers

# %% [markdown]
# ## Build Projection Matrices

# %% [markdown]
# ## Triangulate Points

# %% [markdown]
# ## Filter Outliers

# %% [markdown]
# ## Visualize Sparse Cloud

# %% [markdown]
# ## Save Sparse Cloud
