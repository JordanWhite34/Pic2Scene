# %% [markdown]
# # 08 Meshing and Cleanup
#
# **Purpose:** Convert the dense point cloud into a printable mesh and clean it up.

# %% [markdown]
#     ## Inputs
#     - Dense point cloud
#
#     ## Outputs
#     - Triangle mesh
# - Cleaned watertight-ish mesh candidate

# %% [markdown]
#     ## What needs to be done
#     - [ ] Load dense cloud in Open3D or equivalent
# - [ ] Estimate normals
# - [ ] Run surface reconstruction
# - [ ] Remove isolated components and noise
# - [ ] Fill holes or smooth as needed
# - [ ] Inspect mesh quality visually
# - [ ] Save mesh artifacts

# %% [markdown]
# ## Notes
# - Keep code in this notebook focused on experimentation and visualization.
# - As soon as a block becomes reusable, move it into `src/`.
# - Save intermediate artifacts so later notebooks do not need to recompute everything.

# %% [markdown]
# ## Imports and Paths

# %% [markdown]
# ## Load Dense Cloud

# %% [markdown]
# ## Estimate Normals

# %% [markdown]
# ## Surface Reconstruction

# %% [markdown]
# ## Cleanup and Filtering

# %% [markdown]
# ## Visualize Mesh

# %% [markdown]
# ## Save Mesh
