# %% [markdown]
# # 07 Dense Reconstruction
#
# **Purpose:** Densify the sparse reconstruction into a dense point cloud or depth fusion result.

# %% [markdown]
#     ## Inputs
#     - Refined camera poses
# - Calibrated images
#
#     ## Outputs
#     - Dense point cloud
# - Optional per-view depth maps

# %% [markdown]
#     ## What needs to be done
#     - [ ] Choose a dense reconstruction strategy
# - [ ] Generate depth or dense correspondence estimates
# - [ ] Fuse dense estimates into a point cloud
# - [ ] Filter noise and inconsistent points
# - [ ] Visualize dense cloud quality
# - [ ] Save dense cloud to disk

# %% [markdown]
# ## Notes
# - Keep code in this notebook focused on experimentation and visualization.
# - As soon as a block becomes reusable, move it into `src/`.
# - Save intermediate artifacts so later notebooks do not need to recompute everything.

# %% [markdown]
# ## Imports and Paths

# %% [markdown]
# ## Load Images and Refined Poses

# %% [markdown]
# ## Depth / Dense Matching Step

# %% [markdown]
# ## Fuse Dense Estimates

# %% [markdown]
# ## Filter Dense Cloud

# %% [markdown]
# ## Visualize Dense Cloud

# %% [markdown]
# ## Save Dense Reconstruction
