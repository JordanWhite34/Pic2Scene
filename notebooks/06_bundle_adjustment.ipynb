# %% [markdown]
# # 06 Bundle Adjustment
#
# **Purpose:** Refine camera poses and 3D points by minimizing reprojection error.

# %% [markdown]
#     ## Inputs
#     - Multi-view camera poses
# - 3D points
# - 2D observations / tracks
#
#     ## Outputs
#     - Refined poses
# - Refined 3D points
# - Before / after reprojection error summary

# %% [markdown]
#     ## What needs to be done
#     - [ ] Assemble optimization variables and observation graph
# - [ ] Define reprojection residuals
# - [ ] Choose a solver strategy
# - [ ] Run optimization
# - [ ] Compare reprojection error before and after
# - [ ] Visualize refined reconstruction
# - [ ] Save refined state

# %% [markdown]
# ## Notes
# - Keep code in this notebook focused on experimentation and visualization.
# - As soon as a block becomes reusable, move it into `src/`.
# - Save intermediate artifacts so later notebooks do not need to recompute everything.

# %% [markdown]
# ## Imports and Paths

# %% [markdown]
# ## Load Reconstruction State

# %% [markdown]
# ## Build Optimization Problem

# %% [markdown]
# ## Run Bundle Adjustment

# %% [markdown]
# ## Evaluate Reprojection Error

# %% [markdown]
# ## Visualize Refined Reconstruction

# %% [markdown]
# ## Save Refined Reconstruction
