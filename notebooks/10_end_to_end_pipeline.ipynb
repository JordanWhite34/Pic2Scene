# %% [markdown]
# # 10 End-to-End Pipeline
#
# **Purpose:** Tie the full pipeline together on one dataset and identify weak links.

# %% [markdown]
#     ## Inputs
#     - Raw photo set
# - All saved intermediate artifacts or reusable modules
#
#     ## Outputs
#     - A full reconstruction run
# - Pipeline notes, bottlenecks, and next fixes

# %% [markdown]
#     ## What needs to be done
#     - [ ] Run the workflow stage by stage using saved artifacts when possible
# - [ ] Time each stage
# - [ ] Check where reconstruction quality degrades
# - [ ] Record assumptions and failure points
# - [ ] Generate one final STL candidate
# - [ ] Create a short checklist for next improvements

# %% [markdown]
# ## Notes
# - Keep code in this notebook focused on experimentation and visualization.
# - As soon as a block becomes reusable, move it into `src/`.
# - Save intermediate artifacts so later notebooks do not need to recompute everything.

# %% [markdown]
# ## Imports and Paths

# %% [markdown]
# ## Configuration

# %% [markdown]
# ## Run Full Pipeline

# %% [markdown]
# ## Quality Checks

# %% [markdown]
# ## Timing and Bottleneck Notes

# %% [markdown]
# ## Final Export Review

# %% [markdown]
# ## Next Improvements
