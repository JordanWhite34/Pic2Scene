# %% [markdown]
# # 03 Two-View Geometry
#
# **Purpose:** Recover the relative pose between two calibrated views.

# %% [markdown]
#     ## Inputs
#     - Calibration artifacts
# - Filtered feature matches between two views
#
#     ## Outputs
#     - Essential matrix
# - Relative rotation and translation
# - Inlier match set

# %% [markdown]
#     ## What needs to be done
#     - [ ] Load intrinsics and matched keypoints
# - [ ] Estimate the essential matrix with RANSAC
# - [ ] Recover relative camera pose
# - [ ] Inspect inlier count and failure cases
# - [ ] Optionally visualize epipolar consistency
# - [ ] Save pose estimates for triangulation

# %% [markdown]
# ## Notes
# - Keep code in this notebook focused on experimentation and visualization.
# - As soon as a block becomes reusable, move it into `src/`.
# - Save intermediate artifacts so later notebooks do not need to recompute everything.

# %% [markdown]
# ## Imports and Paths

# %% [markdown]
# ## Load Intrinsics and Matches

# %% [markdown]
# ## Estimate Essential Matrix

# %% [markdown]
# ## Recover Relative Pose

# %% [markdown]
# ## Inspect Inliers

# %% [markdown]
# ## Optional Epipolar Visualization

# %% [markdown]
# ## Save Pose Artifacts
