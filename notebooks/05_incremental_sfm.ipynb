# %% [markdown]
# # 05 Incremental Structure from Motion
#
# **Purpose:** Extend the reconstruction from two views to many views.

# %% [markdown]
#     ## Inputs
#     - Image sequence
# - Initial sparse cloud and camera poses
# - Pairwise matches
#
#     ## Outputs
#     - Camera poses for multiple views
# - Expanded sparse point cloud
# - Track associations between images and 3D points

# %% [markdown]
#     ## What needs to be done
#     - [ ] Choose an image ordering or matching graph
# - [ ] Find 2D-3D correspondences for a new image
# - [ ] Estimate pose with PnP + RANSAC
# - [ ] Triangulate new points between views
# - [ ] Update point tracks and pose graph
# - [ ] Visualize cumulative camera trajectory and sparse cloud

# %% [markdown]
# ## Notes
# - Keep code in this notebook focused on experimentation and visualization.
# - As soon as a block becomes reusable, move it into `src/`.
# - Save intermediate artifacts so later notebooks do not need to recompute everything.

# %% [markdown]
# ## Imports and Paths

# %% [markdown]
# ## Load Existing Reconstruction

# %% [markdown]
# ## Select Next View

# %% [markdown]
# ## Estimate Pose with PnP

# %% [markdown]
# ## Triangulate New Points

# %% [markdown]
# ## Update Tracks and State

# %% [markdown]
# ## Visualize Reconstruction Progress

# %% [markdown]
# ## Save Updated Reconstruction
