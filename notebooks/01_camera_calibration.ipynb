# %% [markdown]
# # 01 Camera Calibration
#
# **Purpose:** Estimate intrinsics and distortion parameters for the camera.

# %% [markdown]
#     ## Inputs
#     - Checkerboard or calibration target images
#
#     ## Outputs
#     - Camera matrix
# - Distortion coefficients
# - Undistorted sample images

# %% [markdown]
#     ## What needs to be done
#     - [ ] Load calibration images
# - [ ] Detect checkerboard corners
# - [ ] Assemble object points and image points
# - [ ] Run camera calibration
# - [ ] Evaluate reprojection error
# - [ ] Save intrinsics and distortion coefficients
# - [ ] Undistort a few samples and visualize results

# %% [markdown]
# ## Notes
# - Keep code in this notebook focused on experimentation and visualization.
# - As soon as a block becomes reusable, move it into `src/`.
# - Save intermediate artifacts so later notebooks do not need to recompute everything.

# %% [markdown]
# ## Imports and Paths

# %% [markdown]
# ## Load Calibration Images

# %% [markdown]
# ## Detect Corners

# %% [markdown]
# ## Calibrate Camera

# %% [markdown]
# ## Reprojection Error Check

# %% [markdown]
# ## Undistortion Demo

# %% [markdown]
# ## Save Calibration Artifacts
