# %% [markdown]
# # 02 Feature Detection and Matching
#
# **Purpose:** Extract local features from images and match them robustly.

# %% [markdown]
#     ## Inputs
#     - Two or more calibrated images of the subject
#
#     ## Outputs
#     - Keypoints and descriptors
# - Match visualizations
# - Filtered inlier candidates

# %% [markdown]
#     ## What needs to be done
#     - [ ] Load a pair of images
# - [ ] Detect keypoints and descriptors
# - [ ] Run descriptor matching
# - [ ] Apply ratio test or cross-check filtering
# - [ ] Visualize raw and filtered matches
# - [ ] Store reusable match data structures

# %% [markdown]
# ## Notes
# - Keep code in this notebook focused on experimentation and visualization.
# - As soon as a block becomes reusable, move it into `src/`.
# - Save intermediate artifacts so later notebooks do not need to recompute everything.

# %% [markdown]
# ## Imports and Paths

# %% [markdown]
# ## Load Image Pair

# %% [markdown]
# ## Detect Features

# %% [markdown]
# ## Match Descriptors

# %% [markdown]
# ## Filter Matches

# %% [markdown]
# ## Visualize Matches

# %% [markdown]
# ## Save Match Artifacts
